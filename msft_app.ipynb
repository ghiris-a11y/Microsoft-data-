# %%
pip install --upgrade numpy pandas matplotlib scipy --user
# Out:
# Requirement already satisfied: numpy in c:\users\ghiri\anaconda3\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\ghiri\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\ghiri\appdata\roaming\python\python39\site-packages (3.9.4)
# Requirement already satisfied: scipy in c:\users\ghiri\anaconda3\lib\site-packages (1.13.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (21.3)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pillow>=8 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (9.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (3.0.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghiri\anaconda3\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\ghiri\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\ghiri\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\ghiri\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ghiri\AppData\Local\Temp\ipykernel_44516\191829022.py", line 2, in <cell line: 2>
#     import pandas as pd
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 53, in <module>
#     from pandas.core import (
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\ops\__init__.py", line 8, in <module>
#     from pandas.core.ops.array_ops import (
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py", line 56, in <module>
#     from pandas.core.computation import expressions
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\computation\expressions.py", line 21, in <module>
#     from pandas.core.computation.check import NUMEXPR_INSTALLED
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\computation\check.py", line 5, in <module>
#     ne = import_optional_dependency("numexpr", errors="warn")
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\ghiri\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\numexpr\__init__.py", line 24, in <module>
#     from numexpr.interpreter import MAX_THREADS, use_vml, __BLOCK_SIZE1__
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "C:\Users\ghiri\anaconda3\lib\runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "C:\Users\ghiri\anaconda3\lib\runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\traitlets\config\application.py", line 846, in launch_instance
#     app.start()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelapp.py", line 677, in start
#     self.io_loop.start()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\tornado\platform\asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\base_events.py", line 601, in run_forever
#     self._run_once()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\base_events.py", line 1905, in _run_once
#     handle._run()
#   File "C:\Users\ghiri\anaconda3\lib\asyncio\events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 471, in dispatch_queue
#     await self.process_one()
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 460, in process_one
#     await dispatch(*args)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 367, in dispatch_shell
#     await result
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\kernelbase.py", line 662, in execute_request
#     reply_content = await reply_content
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\ipkernel.py", line 360, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel\zmqshell.py", line 532, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2863, in run_cell
#     result = self._run_cell(
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2909, in _run_cell
#     return runner(coro)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3106, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3309, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3369, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\ghiri\AppData\Local\Temp\ipykernel_44516\191829022.py", line 2, in <cell line: 2>
#     import pandas as pd
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\__init__.py", line 80, in <module>
#     from pandas.core.api import (
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\__init__.py", line 1, in <module>
#     from pandas.core.arrays.arrow import ArrowExtensionArray
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\arrow\__init__.py", line 5, in <module>
#     from pandas.core.arrays.arrow.array import ArrowExtensionArray
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\arrow\array.py", line 67, in <module>
#     from pandas.core.arrays.masked import BaseMaskedArray
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\arrays\masked.py", line 61, in <module>
#     from pandas.core import (
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\core\nanops.py", line 52, in <module>
#     bn = import_optional_dependency("bottleneck", errors="warn")
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\pandas\compat\_optional.py", line 135, in import_optional_dependency
#     module = importlib.import_module(name)
#   File "C:\Users\ghiri\anaconda3\lib\importlib\__init__.py", line 127, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "C:\Users\ghiri\anaconda3\lib\site-packages\bottleneck\__init__.py", line 7, in <module>
#     from .move import (move_argmax, move_argmin, move_max, move_mean, move_median,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found

# %%
income = pd.read_csv("msft_income.csv", index_col=0)
bs = pd.read_csv("msft_balance_sheet.csv", index_col=0)
cf = pd.read_csv("msft_cashflow.csv", index_col=0)
ratios = pd.read_csv("msft_ratios(1).csv", index_col=0)

# %%
pip install streamlit-jupyter
# Out:
# Collecting streamlit-jupyterNote: you may need to restart the kernel to use updated packages.
#
#   Downloading streamlit_jupyter-0.3.1-py3-none-any.whl (13 kB)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
#     WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\ghiri\anaconda3\lib\site-packages)
# Requirement already satisfied: tqdm in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit-jupyter) (4.64.0)
# Requirement already satisfied: jupyter in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit-jupyter) (1.0.0)
# Collecting stqdm
#   Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Requirement already satisfied: tabulate in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit-jupyter) (0.8.9)
# Collecting ipywidgets>=8
#   Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Requirement already satisfied: streamlit>=1.19 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit-jupyter) (1.50.0)
# Collecting fastcore
#   Downloading fastcore-1.8.9-py3-none-any.whl (79 kB)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from ipywidgets>=8->streamlit-jupyter) (8.2.0)
# Collecting comm>=0.1.3
#   Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Collecting widgetsnbextension~=4.0.14
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Collecting jupyterlab_widgets~=3.0.15
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\ghiri\anaconda3\lib\site-packages (from ipywidgets>=8->streamlit-jupyter) (5.1.1)
# Requirement already satisfied: backcall in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: decorator in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (5.1.1)
# Requirement already satisfied: setuptools>=18.5 in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (61.2.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (3.0.20)
# Requirement already satisfied: pickleshare in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.7.5)
# Requirement already satisfied: stack-data in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.1.2)
# Requirement already satisfied: colorama in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.4.4)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (2.11.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\ghiri\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\ghiri\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.2.5)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.1.6)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (0.9.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (8.0.4)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (21.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (6.33.0)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (4.15.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (1.9.0)
# Requirement already satisfied: packaging<26,>=20 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (21.3)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.3.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (9.1.2)
# Requirement already satisfied: cachetools<7,>=4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (4.2.2)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.0.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (9.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (2.31.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (3.1.45)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<6,>=4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.0)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in c:\users\ghiri\anaconda3\lib\site-packages (from streamlit>=1.19->streamlit-jupyter) (6.1)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\ghiri\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (4.4.0)
# Requirement already satisfied: jinja2 in c:\users\ghiri\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2.11.3)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\ghiri\anaconda3\lib\site-packages (from altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2.10.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\ghiri\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\ghiri\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (5.0.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\ghiri\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\ghiri\anaconda3\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.18.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ghiri\anaconda3\lib\site-packages (from packaging<26,>=20->streamlit>=1.19->streamlit-jupyter) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghiri\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2024.1)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\ghiri\anaconda3\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\ghiri\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghiri\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (1.26.9)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghiri\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghiri\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghiri\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2025.10.5)
# Requirement already satisfied: ipykernel in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter->streamlit-jupyter) (6.9.1)
# Requirement already satisfied: notebook in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter->streamlit-jupyter) (6.4.8)
# Requirement already satisfied: qtconsole in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter->streamlit-jupyter) (5.3.0)
# Requirement already satisfied: jupyter-console in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter->streamlit-jupyter) (6.4.0)
# Requirement already satisfied: nbconvert in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter->streamlit-jupyter) (6.4.4)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\ghiri\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit-jupyter) (6.1.12)
# Requirement already satisfied: nest-asyncio in c:\users\ghiri\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit-jupyter) (1.5.5)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\ghiri\anaconda3\lib\site-packages (from ipykernel->jupyter->streamlit-jupyter) (1.5.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->streamlit-jupyter) (4.9.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter->streamlit-jupyter) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter->streamlit-jupyter) (302)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (1.5.0)
# Requirement already satisfied: defusedxml in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.7.1)
# Requirement already satisfied: testpath in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.4)
# Requirement already satisfied: nbformat>=4.4 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (5.3.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.11.1)
# Requirement already satisfied: bleach in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.1.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.1.2)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\ghiri\anaconda3\lib\site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.5.13)
# Requirement already satisfied: fastjsonschema in c:\users\ghiri\anaconda3\lib\site-packages (from nbformat>=4.4->nbconvert->jupyter->streamlit-jupyter) (2.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ghiri\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit-jupyter) (2.3.1)
# Requirement already satisfied: webencodings in c:\users\ghiri\anaconda3\lib\site-packages (from bleach->nbconvert->jupyter->streamlit-jupyter) (0.5.1)
# Requirement already satisfied: prometheus-client in c:\users\ghiri\anaconda3\lib\site-packages (from notebook->jupyter->streamlit-jupyter) (0.13.1)
# Requirement already satisfied: ipython-genutils in c:\users\ghiri\anaconda3\lib\site-packages (from notebook->jupyter->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\ghiri\anaconda3\lib\site-packages (from notebook->jupyter->streamlit-jupyter) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ghiri\anaconda3\lib\site-packages (from notebook->jupyter->streamlit-jupyter) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\ghiri\anaconda3\lib\site-packages (from notebook->jupyter->streamlit-jupyter) (21.3.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\ghiri\anaconda3\lib\site-packages (from terminado>=0.8.3->notebook->jupyter->streamlit-jupyter) (2.0.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ghiri\anaconda3\lib\site-packages (from argon2-cffi->notebook->jupyter->streamlit-jupyter) (21.2.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ghiri\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook->jupyter->streamlit-jupyter) (1.15.0)
# Requirement already satisfied: pycparser in c:\users\ghiri\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook->jupyter->streamlit-jupyter) (2.21)
# Requirement already satisfied: qtpy>=2.0.1 in c:\users\ghiri\anaconda3\lib\site-packages (from qtconsole->jupyter->streamlit-jupyter) (2.0.1)
# Requirement already satisfied: asttokens in c:\users\ghiri\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (2.0.5)
# Requirement already satisfied: executing in c:\users\ghiri\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\ghiri\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=8->streamlit-jupyter) (0.2.2)
# Installing collected packages: widgetsnbextension, jupyterlab-widgets, comm, ipywidgets, stqdm, fastcore, streamlit-jupyter
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab-widgets 1.0.0
#     Uninstalling jupyterlab-widgets-1.0.0:
#       Successfully uninstalled jupyterlab-widgets-1.0.0
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed comm-0.2.3 fastcore-1.8.9 ipywidgets-8.1.8 jupyterlab-widgets-3.0.16 stqdm-0.0.5 streamlit-jupyter-0.3.1 widgetsnbextension-4.0.15

# %%
from streamlit_jupyter import StreamlitPatcher
StreamlitPatcher().jupyter()

# %%
st.sidebar.title("Navigation")
section = st.sidebar.radio("Go to", ["Overview", "Ratios", "Valuation"])
# Out:
# 2025-11-06 18:09:20.312 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.230
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ghiri\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-11-06 18:09:22.230 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.237 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.240 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.246 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.246 Session state does not function when running a script without `streamlit run`
# 2025-11-06 18:09:22.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.250 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:22.253 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if section == "Overview":
    st.title("Microsoft Financial Overview")
    st.write("### Income Statement")
    st.dataframe(income.tail())
    st.write("### Balance Sheet")
    st.dataframe(bs.tail())
    st.write("### Cash Flow")
    st.dataframe(cf.tail())
# Out:
# 2025-11-06 18:09:54.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.064 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.068 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.070 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.331 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.347 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.365 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-11-06 18:09:54.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
if section == "Ratios":
    st.title("Financial Ratios")
    st.dataframe(ratios)

    st.write("### Ratio Trends")
    selected_ratio = st.selectbox("Select a ratio to plot", ratios.columns)
    st.line_chart(ratios[selected_ratio])

# %%
if section == "Valuation":
    st.title("DCF Valuation")

    last_fcf = cf["Operating Activities"].iloc[-1] - cf["Capital Expenditures"].iloc[-1]
    discount_rate = 0.08
    growth_rate = 0.05
    years = 5

    projected_fcfs = [last_fcf * ((1 + growth_rate) ** i) for i in range(1, years + 1)]
    discounted_fcfs = [fcf / ((1 + discount_rate) ** i) for i, fcf in enumerate(projected_fcfs, 1)]

    terminal_value = projected_fcfs[-1] * (1 + growth_rate) / (discount_rate - growth_rate)
    discounted_terminal = terminal_value / ((1 + discount_rate) ** years)

    dcf_value = sum(discounted_fcfs) + discounted_terminal

    st.metric(label="Estimated DCF Value", value=f"${dcf_value:,.2f}")
